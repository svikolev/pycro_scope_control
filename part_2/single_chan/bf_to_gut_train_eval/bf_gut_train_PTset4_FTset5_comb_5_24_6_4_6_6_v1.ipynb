# %%
#!pip install segmentation-models

# %%
import tensorflow as tf
import tifffile
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger

from sklearn.model_selection import train_test_split

import sys
import os
import datetime

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras import backend as K
from skimage.measure import block_reduce
from tensorflow.keras.preprocessing.image import ImageDataGenerator


import segmentation_models as sm
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
# only allocate what is needed (using for gpu memory testing)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# ### part4 open patches

# %%
# output_file = os.path.join(folder_path, 'bf_patches_256_noNorm_subsel_set5_{}.tiff'.format(ds_name))
# tifffile.imsave(output_file, img_patches_sub)

# output_file = os.path.join(folder_path, 'mask_patches_256_noNorm_subsel_set5_{}.tiff'.format(ds_name))
# tifffile.imsave(output_file, mask_patches_sub)

# %%
folder_path = 'soph_annot_multiDS_7_25_23'
sets = ['5_24','6_4','6_6']
name = 'comb_5_24_6_4_6_6'
ds_name = name
img_patches_sub1 = tifffile.imread(os.path.join(folder_path, 'bf_patches_256_noNorm_subsel_set5_{}.tiff'.format(sets[0])))
mask_patches_sub1 = tifffile.imread(os.path.join(folder_path, 'mask_patches_256_noNorm_subsel_set5_{}.tiff'.format(sets[0])))


img_patches_sub2 = tifffile.imread(os.path.join(folder_path, 'bf_patches_256_noNorm_subsel_set5_{}.tiff'.format(sets[1])))
mask_patches_sub2 = tifffile.imread(os.path.join(folder_path, 'mask_patches_256_noNorm_subsel_set5_{}.tiff'.format(sets[1])))

img_patches_sub3 = tifffile.imread(os.path.join(folder_path, 'bf_patches_256_noNorm_subsel_set5_{}.tiff'.format(sets[2])))
mask_patches_sub3 = tifffile.imread(os.path.join(folder_path, 'mask_patches_256_noNorm_subsel_set5_{}.tiff'.format(sets[2])))


img_patches_sub = np.concatenate((img_patches_sub1,img_patches_sub2,img_patches_sub3),axis = 0)
mask_patches_sub = np.concatenate((mask_patches_sub1,mask_patches_sub2,mask_patches_sub3),axis = 0)

# %%
def center_norm_im_float32(images):
    images_float = images.astype(np.float32)
    mean = np.mean(images_float)
    std = np.std(images_float)
    normalized_stack = (images_float-mean)/std
    return normalized_stack
img_patches_sub = center_norm_im_float32(img_patches_sub)
mask_patches_sub = mask_patches_sub.astype(np.float32)

# %%
# plt.subplot(121)
# plt.hist(img_patches_sub.flatten(),bins = 10);
# plt.subplot(122)
# plt.hist(img_patches_sub.flatten(),bins = 10);

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 5))  # 1 row, 5 columns

for i in range(5):
    # show grayscale images

    ri = np.random.randint(0,img_patches_sub.shape[0])
    axs[i].imshow(img_patches_sub[ri,...], cmap='gray')

    axs[i].imshow(mask_patches_sub[ri,...], cmap='Reds', alpha=0.3)
    #axs[i].axis('off')  # hide the axes

plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(img_patches_sub, mask_patches_sub, test_size = 0.25, random_state = 0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (2701, 256, 256)
# (901, 256, 256)

# %%
X_train = np.stack((X_train,)*1, axis=-1)
y_train = np.stack((y_train,)*1, axis=-1)

print(X_train.shape)
print(y_train.shape)
# Out:
# (2701, 256, 256, 1)
# (2701, 256, 256, 1)

# %%
X_test = np.stack((X_test,)*1, axis=-1)
y_test = np.stack((y_test,)*1, axis=-1)
print(X_test.shape)
print(y_test.shape)
# Out:
# (901, 256, 256, 1)
# (901, 256, 256, 1)

# %%
#New generator with rotation where interpolation that comes with rotation are thresholded in masks.
#This gives a binary mask rather than a mask with interpolated values.
seed=24
batch_size = 32

img_data_gen_args = dict(rotation_range=0,
                         horizontal_flip=True,
                         vertical_flip=True,
                         fill_mode='nearest',
                         preprocessing_function = lambda x: x*np.random.uniform(0.95, 1.05))
                         #brightness_range = (0.95,1.05))
                         #featurewise_center = True,
                         #featurewise_std_normalization = True)#,
                         #preprocessing_function = lambda x: x*np.random.uniform(0.95, 1.05))
                         #brightness_range = (0.95,1.05))


mask_data_gen_args = dict(rotation_range=0,
                         horizontal_flip=True,
                         vertical_flip=True,
                         fill_mode='nearest',
                         brightness_range = (0.95,1.05),
                         preprocessing_function = lambda x: np.where(x>0, 1, 0).astype(x.dtype))

image_data_generator = ImageDataGenerator(**img_data_gen_args)
image_data_generator.fit(X_train, augment=True, seed=seed)

image_generator = image_data_generator.flow(X_train, seed=seed,batch_size = batch_size)
valid_img_generator = image_data_generator.flow(X_test, seed=seed,batch_size = batch_size)

mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
mask_data_generator.fit(y_train, augment=True, seed=seed)

mask_generator = mask_data_generator.flow(y_train, seed=seed,batch_size = batch_size)
valid_mask_generator = mask_data_generator.flow(y_test, seed=seed,batch_size = batch_size)

# %%
def my_image_mask_generator(image_generator, mask_generator):
    train_generator = zip(image_generator, mask_generator)
    for (img, mask) in train_generator:
        yield (img, mask)

train_gen = my_image_mask_generator(image_generator,mask_generator)
test_gen = my_image_mask_generator(valid_img_generator,valid_mask_generator)

# %%
x = image_generator.next()
y = mask_generator.next()

print('x batch:', x.shape)
print('y batch:', y.shape)

fig, axs = plt.subplots(2, 5, figsize=(20, 10))  # 1 row, 5 columns

for i in range(5):
    # show grayscale images

    ri = np.random.randint(0,32)
    axs[0,i].imshow(x[ri,...,0], cmap='gray')
    axs[0,i].imshow(y[ri,...,0], cmap='Reds', alpha=0.3)
    axs[0,i].title.set_text('x:{} y: {}'.format(x[ri,...,0].dtype,y[ri,...,0].dtype))
    
#     axs[1,i].imshow(x[ri+1,...,0], cmap='gray')
#     axs[1,i].imshow(y[i+1,...,0], cmap='Reds', alpha=0.3)
#     axs[1,i].title.set_text('x:{} y: {}'.format(x[ri,...,0].dtype,y[ri,...,0].dtype))
    
    axs[1,i].hist(x[ri,...,0].flatten(), bins = 20,alpha = 0.3)
    axs[1,i].hist(y[ri,...,0].flatten(), bins = 20,alpha = 0.3)

plt.show()
# Out:
# x batch: (32, 256, 256, 1)
# y batch: (32, 256, 256, 1)

# %%
x[0,0,0,0]
# Out:
# -0.9893616

# %%
def get_1c_PT_unet(weights_path):
    N = 1
    BACKBONE = 'resnet18'
    preprocess_input1 = sm.get_preprocessing(BACKBONE)
    base_model = sm.Unet(BACKBONE, encoder_weights='imagenet')
    inp = Input(shape =(None,None, N))
    l1 = Conv2D(3,(1,1))(inp) # map N channels data to 3 channels
    out = base_model(l1)
    model = Model(inp, out, name=base_model.name)
    model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
    #checkpoint_path = 'models/bf_to_gut_tl/set4patches256_meanstdNorm_imgenBR05_backresnet18_weightimagenetFencoder4ep_v4.hdf5'
    checkpoint_path = weights_path
    model.load_weights(checkpoint_path)
    return model

ppp = 'models/bf_to_gut_tl/set4_50im_patches256_meanstdNorm_imgenBR05_backresnet18_weightimagenetFencoder4ep_v4.hdf5'
model = get_1c_PT_unet(ppp)

# %%
checkpoint_path = 'models/bf_to_gut_tl/base_set4_50im_p256_v4_FT_set5_ds_{}_v1.hdf5'.format(ds_name)

checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, save_weights_only=True,mode='min')

# logdirectory
log_fname = 'models/bf_to_gut_tl/base_set4_50im_p256_v4_FT_set5_ds_{}_v1.csv'.format(ds_name)
csvlogger = CSVLogger(filename=log_fname, separator=",", append=True)

directory = os.path.dirname(log_fname)
if not os.path.exists(directory):
    os.makedirs(directory)
with open(log_fname, 'w') as f:
    pass

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 1)]   0
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, None, 3)     6
# _________________________________________________________________
# model_1 (Model)              (None, None, None, 1)     14340570
# =================================================================
# Total params: 14,340,576
# Trainable params: 14,330,650
# Non-trainable params: 9,926
# _________________________________________________________________

# %%
# from segmentation_models.utils import set_trainable
# set_trainable(model)

# %%
# # set all layers trainable and recompile with same call to compile as before
# for layer in model.layers:
#     layer.trainable = True
# model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])
# # default learning rate is 0.0001

# %%
history = model.fit(train_gen,
                    validation_data=test_gen,
                    steps_per_epoch=len(X_train) // batch_size,
                    validation_steps=len(X_train) // batch_size,
                    epochs=60,
                    callbacks=[checkpoint,csvlogger])
# Out:
# Epoch 1/60
# 84/84 [==============================] - 22s 256ms/step - loss: 0.6752 - iou_score: 0.4972 - val_loss: 0.6778 - val_iou_score: 0.5079
# Epoch 2/60
# 84/84 [==============================] - 19s 226ms/step - loss: 0.5556 - iou_score: 0.5730 - val_loss: 0.6244 - val_iou_score: 0.5240
# Epoch 3/60
# 84/84 [==============================] - 18s 219ms/step - loss: 0.4975 - iou_score: 0.6149 - val_loss: 0.5482 - val_iou_score: 0.5748
# Epoch 4/60
# 84/84 [==============================] - 20s 233ms/step - loss: 0.4488 - iou_score: 0.6527 - val_loss: 0.5014 - val_iou_score: 0.6227
# Epoch 5/60
# 84/84 [==============================] - 19s 223ms/step - loss: 0.4290 - iou_score: 0.6683 - val_loss: 0.5764 - val_iou_score: 0.5740
# Epoch 6/60
# 84/84 [==============================] - 17s 205ms/step - loss: 0.3852 - iou_score: 0.7024 - val_loss: 0.5010 - val_iou_score: 0.6361
# Epoch 7/60
# 84/84 [==============================] - 19s 225ms/step - loss: 0.3504 - iou_score: 0.7292 - val_loss: 0.4796 - val_iou_score: 0.6408
# Epoch 8/60
# 84/84 [==============================] - 18s 212ms/step - loss: 0.3384 - iou_score: 0.7394 - val_loss: 0.4995 - val_iou_score: 0.6372
# Epoch 9/60
# 84/84 [==============================] - 19s 224ms/step - loss: 0.2878 - iou_score: 0.7774 - val_loss: 0.4059 - val_iou_score: 0.6952
# Epoch 10/60
# 84/84 [==============================] - 17s 200ms/step - loss: 0.2673 - iou_score: 0.7928 - val_loss: 0.3996 - val_iou_score: 0.7108
# Epoch 11/60
# 84/84 [==============================] - 18s 217ms/step - loss: 0.2553 - iou_score: 0.8024 - val_loss: 0.3549 - val_iou_score: 0.7332
# Epoch 12/60
# 84/84 [==============================] - 18s 217ms/step - loss: 0.2312 - iou_score: 0.8196 - val_loss: 0.3565 - val_iou_score: 0.7354
# Epoch 13/60
# 84/84 [==============================] - 19s 229ms/step - loss: 0.2136 - iou_score: 0.8347 - val_loss: 0.3441 - val_iou_score: 0.7432
# Epoch 14/60
# 84/84 [==============================] - 19s 221ms/step - loss: 0.2061 - iou_score: 0.8398 - val_loss: 0.3197 - val_iou_score: 0.7631
# Epoch 15/60
# 84/84 [==============================] - 19s 223ms/step - loss: 0.1935 - iou_score: 0.8490 - val_loss: 0.2998 - val_iou_score: 0.7754
# Epoch 16/60
# 84/84 [==============================] - 18s 217ms/step - loss: 0.1916 - iou_score: 0.8512 - val_loss: 0.3386 - val_iou_score: 0.7509
# Epoch 17/60
# 84/84 [==============================] - 19s 227ms/step - loss: 0.1874 - iou_score: 0.8540 - val_loss: 0.3026 - val_iou_score: 0.7745
# Epoch 18/60
# 84/84 [==============================] - 19s 228ms/step - loss: 0.1854 - iou_score: 0.8554 - val_loss: 0.3056 - val_iou_score: 0.7773
# Epoch 19/60
# 84/84 [==============================] - 18s 213ms/step - loss: 0.1782 - iou_score: 0.8615 - val_loss: 0.2984 - val_iou_score: 0.7787
# Epoch 20/60
# 84/84 [==============================] - 19s 221ms/step - loss: 0.1624 - iou_score: 0.8733 - val_loss: 0.2716 - val_iou_score: 0.8020
# Epoch 21/60
# 84/84 [==============================] - 18s 215ms/step - loss: 0.1561 - iou_score: 0.8781 - val_loss: 0.2515 - val_iou_score: 0.8150
# Epoch 22/60
# 84/84 [==============================] - 19s 224ms/step - loss: 0.1563 - iou_score: 0.8774 - val_loss: 0.2736 - val_iou_score: 0.7986
# Epoch 23/60
# 84/84 [==============================] - 19s 229ms/step - loss: 0.1490 - iou_score: 0.8834 - val_loss: 0.2551 - val_iou_score: 0.8162
# Epoch 24/60
# 84/84 [==============================] - 18s 215ms/step - loss: 0.1380 - iou_score: 0.8916 - val_loss: 0.2508 - val_iou_score: 0.8174
# Epoch 25/60
# 84/84 [==============================] - 18s 220ms/step - loss: 0.1344 - iou_score: 0.8948 - val_loss: 0.2362 - val_iou_score: 0.8286
# Epoch 26/60
# 84/84 [==============================] - 18s 209ms/step - loss: 0.1256 - iou_score: 0.9015 - val_loss: 0.2282 - val_iou_score: 0.8303
# Epoch 27/60
# 84/84 [==============================] - 19s 221ms/step - loss: 0.1232 - iou_score: 0.9036 - val_loss: 0.2177 - val_iou_score: 0.8409
# Epoch 28/60
# 84/84 [==============================] - 19s 232ms/step - loss: 0.1249 - iou_score: 0.9018 - val_loss: 0.2697 - val_iou_score: 0.8056
# Epoch 29/60
# 84/84 [==============================] - 18s 213ms/step - loss: 0.1290 - iou_score: 0.8989 - val_loss: 0.2332 - val_iou_score: 0.8300
# Epoch 30/60
# 84/84 [==============================] - 18s 216ms/step - loss: 0.1249 - iou_score: 0.9019 - val_loss: 0.2516 - val_iou_score: 0.8220
# Epoch 31/60
# 84/84 [==============================] - 19s 221ms/step - loss: 0.1167 - iou_score: 0.9081 - val_loss: 0.2265 - val_iou_score: 0.8367
# Epoch 32/60
# 84/84 [==============================] - 19s 221ms/step - loss: 0.1119 - iou_score: 0.9122 - val_loss: 0.2243 - val_iou_score: 0.8415
# Epoch 33/60
# 84/84 [==============================] - 20s 235ms/step - loss: 0.1091 - iou_score: 0.9140 - val_loss: 0.2065 - val_iou_score: 0.8485
# Epoch 34/60
# 84/84 [==============================] - 18s 212ms/step - loss: 0.1075 - iou_score: 0.9155 - val_loss: 0.2023 - val_iou_score: 0.8548
# Epoch 35/60
# 84/84 [==============================] - 19s 231ms/step - loss: 0.0995 - iou_score: 0.9213 - val_loss: 0.1902 - val_iou_score: 0.8602
# Epoch 36/60
# 84/84 [==============================] - 17s 205ms/step - loss: 0.1010 - iou_score: 0.9207 - val_loss: 0.2120 - val_iou_score: 0.8459
# Epoch 37/60
# 84/84 [==============================] - 19s 228ms/step - loss: 0.1017 - iou_score: 0.9198 - val_loss: 0.1921 - val_iou_score: 0.8595
# Epoch 38/60
# 84/84 [==============================] - 19s 224ms/step - loss: 0.0977 - iou_score: 0.9230 - val_loss: 0.2089 - val_iou_score: 0.8491
# Epoch 39/60
# 84/84 [==============================] - 18s 215ms/step - loss: 0.0968 - iou_score: 0.9238 - val_loss: 0.1905 - val_iou_score: 0.8587
# Epoch 40/60
# 84/84 [==============================] - 19s 223ms/step - loss: 0.0943 - iou_score: 0.9255 - val_loss: 0.1989 - val_iou_score: 0.8570
# Epoch 41/60
# 84/84 [==============================] - 18s 215ms/step - loss: 0.0931 - iou_score: 0.9267 - val_loss: 0.1925 - val_iou_score: 0.8617
# Epoch 42/60
# 84/84 [==============================] - 18s 217ms/step - loss: 0.0925 - iou_score: 0.9269 - val_loss: 0.1945 - val_iou_score: 0.8599
# Epoch 43/60
# 84/84 [==============================] - 18s 214ms/step - loss: 0.0949 - iou_score: 0.9253 - val_loss: 0.1936 - val_iou_score: 0.8574
# Epoch 44/60
# 84/84 [==============================] - 18s 213ms/step - loss: 0.0936 - iou_score: 0.9257 - val_loss: 0.1925 - val_iou_score: 0.8595
# Epoch 45/60
# 84/84 [==============================] - 19s 221ms/step - loss: 0.0913 - iou_score: 0.9281 - val_loss: 0.1772 - val_iou_score: 0.8714
# Epoch 46/60
# 84/84 [==============================] - 17s 207ms/step - loss: 0.0877 - iou_score: 0.9306 - val_loss: 0.1845 - val_iou_score: 0.8693
# Epoch 47/60
# 84/84 [==============================] - 18s 216ms/step - loss: 0.0874 - iou_score: 0.9314 - val_loss: 0.1841 - val_iou_score: 0.8655
# Epoch 48/60
# 84/84 [==============================] - 18s 218ms/step - loss: 0.0847 - iou_score: 0.9328 - val_loss: 0.1742 - val_iou_score: 0.8714
# Epoch 49/60
# 84/84 [==============================] - 17s 205ms/step - loss: 0.0861 - iou_score: 0.9320 - val_loss: 0.1870 - val_iou_score: 0.8684
# Epoch 50/60
# 84/84 [==============================] - 18s 215ms/step - loss: 0.0834 - iou_score: 0.9342 - val_loss: 0.1764 - val_iou_score: 0.8753
# Epoch 51/60
# 84/84 [==============================] - 18s 213ms/step - loss: 0.0814 - iou_score: 0.9356 - val_loss: 0.1831 - val_iou_score: 0.8718
# Epoch 52/60
# 84/84 [==============================] - 18s 217ms/step - loss: 0.0826 - iou_score: 0.9348 - val_loss: 0.2150 - val_iou_score: 0.8467
# Epoch 53/60
# 84/84 [==============================] - 17s 205ms/step - loss: 0.0875 - iou_score: 0.9309 - val_loss: 0.1862 - val_iou_score: 0.8672
# Epoch 54/60
# 84/84 [==============================] - 18s 217ms/step - loss: 0.0920 - iou_score: 0.9277 - val_loss: 0.2242 - val_iou_score: 0.8385
# Epoch 55/60
# 84/84 [==============================] - 18s 219ms/step - loss: 0.0915 - iou_score: 0.9275 - val_loss: 0.2005 - val_iou_score: 0.8573
# Epoch 56/60
# 84/84 [==============================] - 19s 222ms/step - loss: 0.0867 - iou_score: 0.9316 - val_loss: 0.1924 - val_iou_score: 0.8640
# Epoch 57/60
# 84/84 [==============================] - 19s 224ms/step - loss: 0.0854 - iou_score: 0.9325 - val_loss: 0.1850 - val_iou_score: 0.8652
# Epoch 58/60
# 84/84 [==============================] - 19s 225ms/step - loss: 0.0821 - iou_score: 0.9349 - val_loss: 0.1807 - val_iou_score: 0.8735
# Epoch 59/60
# 84/84 [==============================] - 18s 218ms/step - loss: 0.0800 - iou_score: 0.9367 - val_loss: 0.1751 - val_iou_score: 0.8755
# Epoch 60/60
# 84/84 [==============================] - 20s 234ms/step - loss: 0.0780 - iou_score: 0.9380 - val_loss: 0.1700 - val_iou_score: 0.8793

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize = [6,3])
plt.subplot(121)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history.history['iou_score']
#acc = history.history['accuracy']
val_acc = history.history['val_iou_score']
#val_acc = history.history['val_accuracy']
plt.subplot(122)
plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
model.load_weights(checkpoint_path)

#IOU
y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(y_test, y_pred_thresholded)
union = np.logical_or(y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.8884525549848052

# %%
model.load_weights(checkpoint_path)

#IOU
y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(y_test, y_pred_thresholded)
union = np.logical_or(y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.8720188252303179

# %%
test_img_number = np.random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
print(test_img.shape)
test_img_input=np.expand_dims(test_img, 0)
ground_truth=y_test[test_img_number]
prediction = model.predict(test_img_input)
prediction = prediction[0,:,:,0]

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# (256, 256, 1)

# %%
#Fit the model
history = model.fit(train_gen,
                    validation_data=test_gen,
                    steps_per_epoch=len(X_train) // batch_size,
                    validation_steps=len(X_train) // batch_size,
                    epochs=30,
                    callbacks=[checkpoint,csvlogger])

# %%
worm_imgs_norm = center_norm_im_float32(worm_imgs_norm) #global_norm_data_float32(bf_stack)
mask_imgs_norm = mask_imgs_norm.astype(np.float32)

# %%
# Out:
# 4.2384415

# %%
test_img_number = np.random.randint(0, worm_imgs_norm.shape[0])
print(test_img_number)
test_img = worm_imgs_norm[test_img_number,...]

test_img = np.stack((test_img,)*1, axis=-1)
test_img_input=np.expand_dims(test_img, 0)
ground_truth=mask_imgs_norm[test_img_number,...]
prediction = model.predict(test_img_input)
prediction = prediction[0,:,:,0]

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 23

# %%
test_img_number = np.random.randint(0, worm_imgs_norm.shape[0])
print(test_img_number)
test_img = worm_imgs_norm[test_img_number,...]

test_img = np.stack((test_img,)*1, axis=-1)
test_img_input=np.expand_dims(test_img, 0)
ground_truth=mask_imgs_norm[test_img_number,...]
prediction = model.predict(test_img_input)
prediction = prediction[0,:,:,0]

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 4

# %%
model.load_weights('models/bf_to_gut_tl/sel_patches_backresnet18_weightimagenet_v1.hdf5')

# %%
#IOU
y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(y_test, y_pred_thresholded)
union = np.logical_or(y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.8341554104238993

# %%
test_img_number = np.random.randint(0, worm_imgs_norm.shape[0])
test_img = worm_imgs_norm[test_img_number,...]

test_img = np.stack((test_img,)*1, axis=-1)
test_img_input=np.expand_dims(test_img, 0)
ground_truth=mask_imgs_norm[test_img_number,...]
prediction = model.predict(test_img_input)
prediction = prediction[0,:,:,0]

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()

# %%
test_img_number = np.random.randint(0, worm_imgs_norm.shape[0])
test_img = worm_imgs_norm[test_img_number,...]

test_img = np.stack((test_img,)*1, axis=-1)
test_img_input=np.expand_dims(test_img, 0)
ground_truth=mask_imgs_norm[test_img_number,...]
prediction = model.predict(test_img_input)
prediction = prediction[0,:,:,0]

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()

# %%
test_img_number = np.random.randint(0, worm_imgs_norm.shape[0])
test_img = worm_imgs_norm[test_img_number,...]

test_img = np.stack((test_img,)*1, axis=-1)
test_img_input=np.expand_dims(test_img, 0)
ground_truth=mask_imgs_norm[test_img_number,...]
prediction = model.predict(test_img_input)
prediction = prediction[0,:,:,0]

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:], cmap='Reds',alpha = 0.7)
plt.imshow(prediction, cmap='Blues',alpha = 0.7)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()

# %%
annot_dir = 'soph_annot_bact_noPool_7_22_23'
annot_file_list = os.listdir(annot_dir)
annot_file_list

s1 = tifffile.imread(os.path.join(annot_dir,annot_file_list[3]))
s1.shape
# Out:
# (4, 2048, 2048)

# %%
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(s1[i])

# %%
plt.subplot(1,2,1)
plt.hist(s1[0].flatten(),bins = 10);
plt.subplot(1,2,2)
plt.hist(s1[3].flatten(),bins = 10);

# %%
bf_norm = global_norm_data_float32(s1[:1,...])

# %%
test_img = np.stack((bf_norm,)*1, axis=-1)
test_img.shape
# Out:
# (1, 2048, 2048, 1)

# %%
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('bf')
plt.imshow(test_img[0,:,:,0], cmap='gray')
plt.subplot(232)
plt.title('annot')
plt.imshow(s1[3], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(model.predict(test_img)[0,...,0], cmap='gray')
