# %%
#!pip install segmentation-models

# %%
import tensorflow as tf
import tifffile
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger

from sklearn.model_selection import train_test_split

import sys
import os
import datetime

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras import backend as K
from skimage.measure import block_reduce
from tensorflow.keras.preprocessing.image import ImageDataGenerator


import segmentation_models as sm
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
# only allocate what is needed (using for gpu memory testing)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# ## open patches

# %%
folder_path = 'patches'
bf_patches = tifffile.imread(os.path.join(folder_path, '53_gut_exp3_patch_bf.tiff'))
greenc_patches = tifffile.imread(os.path.join(folder_path, '53_gut_exp3_patch_gc.tiff'))
mask_patches = tifffile.imread(os.path.join(folder_path, '53_gut_exp3_patch_mask.tiff'))

# %%
print(bf_patches.shape)
print(greenc_patches.shape)
print(mask_patches.shape)
# Out:
# (1115, 256, 256)
# (1115, 256, 256)
# (1115, 256, 256)

# %%
combined_array = np.stack((bf_patches, greenc_patches), axis=-1)
combined_array.shape
# Out:
# (1115, 256, 256, 2)

# %%
X_train, X_test, y_train, y_test = train_test_split(combined_array, mask_patches, test_size = 0.20, random_state = 0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (892, 256, 256, 2)
# (223, 256, 256, 2)

# %%
y_train = np.stack((y_train,)*1, axis=-1)
print(y_train.shape)
# Out:
# (892, 256, 256, 1)

# %%
y_test = np.stack((y_test,)*1, axis=-1)
print(y_test.shape)
# Out:
# (223, 256, 256, 1)

# %%
#New generator with rotation where interpolation that comes with rotation are thresholded in masks.
#This gives a binary mask rather than a mask with interpolated values.
seed=24
batch_size = 32

img_data_gen_args = dict(rotation_range=0,
                         horizontal_flip=True,
                         vertical_flip=True,
                         fill_mode='nearest',
                         preprocessing_function = lambda x: x*np.random.uniform(0.95, 1.05))
                         #brightness_range = (0.95,1.05))
                         #featurewise_center = True,
                         #featurewise_std_normalization = True)#,
                         #preprocessing_function = lambda x: x*np.random.uniform(0.95, 1.05))
                         #brightness_range = (0.95,1.05))


mask_data_gen_args = dict(rotation_range=0,
                         horizontal_flip=True,
                         vertical_flip=True,
                         fill_mode='nearest',
                         brightness_range = (0.95,1.05),
                         preprocessing_function = lambda x: np.where(x>0, 1, 0).astype(x.dtype))

image_data_generator = ImageDataGenerator(**img_data_gen_args)
image_data_generator.fit(X_train, augment=True, seed=seed)

image_generator = image_data_generator.flow(X_train, seed=seed,batch_size = batch_size)
valid_img_generator = image_data_generator.flow(X_test, seed=seed,batch_size = batch_size)

mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
mask_data_generator.fit(y_train, augment=True, seed=seed)

mask_generator = mask_data_generator.flow(y_train, seed=seed,batch_size = batch_size)
valid_mask_generator = mask_data_generator.flow(y_test, seed=seed,batch_size = batch_size)
# Out:
# /shared/centos7/anaconda3/2021.07-TF/lib/python3.8/site-packages/keras_preprocessing/image/image_data_generator.py:931: UserWarning: Expected input to be images (as Numpy array) following the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3 or 4 channels on axis 3. However, it was passed an array with shape (892, 256, 256, 2) (2 channels).
#   warnings.warn(
# /shared/centos7/anaconda3/2021.07-TF/lib/python3.8/site-packages/keras_preprocessing/image/numpy_array_iterator.py:120: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (892, 256, 256, 2) (2 channels).
#   warnings.warn('NumpyArrayIterator is set to use the '
# /shared/centos7/anaconda3/2021.07-TF/lib/python3.8/site-packages/keras_preprocessing/image/numpy_array_iterator.py:120: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (223, 256, 256, 2) (2 channels).
#   warnings.warn('NumpyArrayIterator is set to use the '

# %%
def my_image_mask_generator(image_generator, mask_generator):
    train_generator = zip(image_generator, mask_generator)
    for (img, mask) in train_generator:
        yield (img, mask)

train_gen = my_image_mask_generator(image_generator,mask_generator)
test_gen = my_image_mask_generator(valid_img_generator,valid_mask_generator)

# %%
x = image_generator.next()
y = mask_generator.next()

print('x batch:', x.shape)
print('y batch:', y.shape)

fig, axs = plt.subplots(2, 5, figsize=(20, 10))  # 1 row, 5 columns

for i in range(5):
    # show grayscale images

    ri = np.random.randint(0,32)
    axs[0,i].imshow(x[ri,...,0], cmap='gray')
    axs[0,i].imshow(y[ri,...,0], cmap='Reds', alpha=0.3)
    axs[0,i].title.set_text('x:{} y: {}'.format(x[ri,...,0].dtype,y[ri,...,0].dtype))
    
#     axs[1,i].imshow(x[ri+1,...,0], cmap='gray')
#     axs[1,i].imshow(y[i+1,...,0], cmap='Reds', alpha=0.3)
#     axs[1,i].title.set_text('x:{} y: {}'.format(x[ri,...,0].dtype,y[ri,...,0].dtype))
    
    axs[1,i].hist(x[ri,...,0].flatten(), bins = 20,alpha = 0.3)
    axs[1,i].hist(y[ri,...,0].flatten(), bins = 20,alpha = 0.3)

plt.show()
# Out:
# x batch: (32, 256, 256, 2)
# y batch: (32, 256, 256, 1)

# %%
x.shape
# Out:
# (32, 256, 256, 2)

# %%
N = x.shape[-1]

# define the model
BACKBONE = 'resnet18'
preprocess_input1 = sm.get_preprocessing(BACKBONE)
base_model = sm.Unet(BACKBONE, encoder_weights='imagenet',encoder_freeze=False)
inp = Input(shape =(None,None, N))
l1 = Conv2D(3,(1,1))(inp) # map N channels data to 3 channels
out = base_model(l1)
model = Model(inp, out, name=base_model.name)
model.compile('Adam', loss=sm.losses.bce_jaccard_loss, metrics=[sm.metrics.iou_score])

# checkpoint path
checkpoint_path = 'bfg_to_gut_backresnet18_exp3_v1.h5'
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, save_weights_only=True,mode='min')

# logdirectory
log_fname = 'bfg_to_gut_backresnet18_exp1_v3.csv'
csvlogger = CSVLogger(filename=log_fname, separator=",", append=True)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 2)]   0
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, None, 3)     9
# _________________________________________________________________
# model_1 (Model)              (None, None, None, 1)     14340570
# =================================================================
# Total params: 14,340,579
# Trainable params: 14,330,653
# Non-trainable params: 9,926
# _________________________________________________________________

# %%
model.load_weights('bfg_to_gut_backresnet18_v1.h5')

# %%
#Fit the model
history = model.fit(train_gen,
                    validation_data=test_gen,
                    steps_per_epoch=len(X_train) // batch_size,
                    validation_steps=len(X_train) // batch_size,
                    epochs=10,
                    callbacks=[checkpoint,csvlogger])
# Out:
# Epoch 1/10
# 27/27 [==============================] - 25s 922ms/step - loss: 0.6341 - iou_score: 0.5378 - val_loss: 0.9206 - val_iou_score: 0.5107
# Epoch 2/10
# 27/27 [==============================] - 17s 621ms/step - loss: 0.5319 - iou_score: 0.5957 - val_loss: 0.6431 - val_iou_score: 0.6205
# Epoch 3/10
# 27/27 [==============================] - 17s 636ms/step - loss: 0.5109 - iou_score: 0.6150 - val_loss: 0.6041 - val_iou_score: 0.6082
# Epoch 4/10
# 27/27 [==============================] - 16s 597ms/step - loss: 0.4693 - iou_score: 0.6466 - val_loss: 0.7051 - val_iou_score: 0.5643
# Epoch 5/10
# 27/27 [==============================] - 16s 588ms/step - loss: 0.4562 - iou_score: 0.6629 - val_loss: 0.6394 - val_iou_score: 0.5822
# Epoch 6/10
# 27/27 [==============================] - 16s 605ms/step - loss: 0.4189 - iou_score: 0.6924 - val_loss: 0.5500 - val_iou_score: 0.6189
# Epoch 7/10
# 27/27 [==============================] - 16s 575ms/step - loss: 0.4099 - iou_score: 0.7008 - val_loss: 0.6241 - val_iou_score: 0.5899
# Epoch 8/10
# 27/27 [==============================] - 17s 624ms/step - loss: 0.3717 - iou_score: 0.7326 - val_loss: 0.4739 - val_iou_score: 0.6781
# Epoch 9/10
# 27/27 [==============================] - 17s 612ms/step - loss: 0.3419 - iou_score: 0.7477 - val_loss: 0.4360 - val_iou_score: 0.6920
# Epoch 10/10
# 27/27 [==============================] - 17s 626ms/step - loss: 0.3360 - iou_score: 0.7521 - val_loss: 0.4267 - val_iou_score: 0.7098

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
#acc = history.history['accuracy']
val_acc = history.history['val_iou_score']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

#IOU
y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(y_test, y_pred_thresholded)
union = np.logical_or(y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.7382293266017729

# %%
test_img_number = np.random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
print(test_img.shape)
test_img_input=np.expand_dims(test_img, 0)
ground_truth=y_test[test_img_number]
prediction = model.predict(test_img_input)
prediction = prediction[0,:,:,0]

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# (256, 256, 2)

# %%
#Fit the model
history = model.fit(train_gen,
                    validation_data=test_gen,
                    steps_per_epoch=len(X_train) // batch_size,
                    validation_steps=len(X_train) // batch_size,
                    epochs=20,
                    callbacks=[checkpoint,csvlogger])
# Out:
# Epoch 1/20
# 27/27 [==============================] - 17s 635ms/step - loss: 0.2800 - iou_score: 0.7854 - val_loss: 0.3902 - val_iou_score: 0.7355
# Epoch 2/20
# 27/27 [==============================] - 17s 638ms/step - loss: 0.2900 - iou_score: 0.7918 - val_loss: 0.3766 - val_iou_score: 0.7358
# Epoch 3/20
# 27/27 [==============================] - 15s 571ms/step - loss: 0.2832 - iou_score: 0.7951 - val_loss: 0.3877 - val_iou_score: 0.7304
# Epoch 4/20
# 27/27 [==============================] - 17s 611ms/step - loss: 0.2672 - iou_score: 0.8092 - val_loss: 0.3252 - val_iou_score: 0.7652
# Epoch 5/20
# 27/27 [==============================] - 16s 581ms/step - loss: 0.2589 - iou_score: 0.8161 - val_loss: 0.3305 - val_iou_score: 0.7635
# Epoch 6/20
# 27/27 [==============================] - 16s 582ms/step - loss: 0.2461 - iou_score: 0.8227 - val_loss: 0.3483 - val_iou_score: 0.7486
# Epoch 7/20
# 27/27 [==============================] - 16s 585ms/step - loss: 0.2306 - iou_score: 0.8311 - val_loss: 0.3276 - val_iou_score: 0.7660
# Epoch 8/20
# 27/27 [==============================] - 16s 590ms/step - loss: 0.2222 - iou_score: 0.8388 - val_loss: 0.3418 - val_iou_score: 0.7628
# Epoch 9/20
# 27/27 [==============================] - 17s 615ms/step - loss: 0.2243 - iou_score: 0.8383 - val_loss: 0.3021 - val_iou_score: 0.7835
# Epoch 10/20
# 27/27 [==============================] - 17s 624ms/step - loss: 0.1913 - iou_score: 0.8589 - val_loss: 0.3012 - val_iou_score: 0.7936
# Epoch 11/20
# 27/27 [==============================] - 15s 571ms/step - loss: 0.2049 - iou_score: 0.8563 - val_loss: 0.7455 - val_iou_score: 0.6136
# Epoch 12/20
# 27/27 [==============================] - 17s 634ms/step - loss: 0.1957 - iou_score: 0.8638 - val_loss: 0.2832 - val_iou_score: 0.8036
# Epoch 13/20
# 27/27 [==============================] - 16s 575ms/step - loss: 0.2121 - iou_score: 0.8518 - val_loss: 0.2983 - val_iou_score: 0.7960
# Epoch 14/20
# 27/27 [==============================] - 16s 576ms/step - loss: 0.1950 - iou_score: 0.8568 - val_loss: 0.3153 - val_iou_score: 0.7885
# Epoch 15/20
# 27/27 [==============================] - 16s 593ms/step - loss: 0.2064 - iou_score: 0.8592 - val_loss: 0.2797 - val_iou_score: 0.8019
# Epoch 16/20
# 27/27 [==============================] - 17s 613ms/step - loss: 0.1893 - iou_score: 0.8674 - val_loss: 0.2481 - val_iou_score: 0.8241
# Epoch 17/20
# 27/27 [==============================] - 16s 586ms/step - loss: 0.2016 - iou_score: 0.8658 - val_loss: 0.2572 - val_iou_score: 0.8237
# Epoch 18/20
# 27/27 [==============================] - 17s 618ms/step - loss: 0.1760 - iou_score: 0.8761 - val_loss: 0.2431 - val_iou_score: 0.8300
# Epoch 19/20
# 27/27 [==============================] - 16s 580ms/step - loss: 0.1880 - iou_score: 0.8710 - val_loss: 0.3489 - val_iou_score: 0.7682
# Epoch 20/20
# 27/27 [==============================] - 16s 600ms/step - loss: 0.1894 - iou_score: 0.8627 - val_loss: 0.2909 - val_iou_score: 0.8025

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
#acc = history.history['accuracy']
val_acc = history.history['val_iou_score']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

#IOU
y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(y_test, y_pred_thresholded)
union = np.logical_or(y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.8448287331370257

# %%
test_img_number = np.random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
print(test_img.shape)
test_img_input=np.expand_dims(test_img, 0)
ground_truth=y_test[test_img_number]
prediction = model.predict(test_img_input)
prediction = prediction[0,:,:,0]

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# (256, 256, 2)

# %%
#Fit the model
history = model.fit(train_gen,
                    validation_data=test_gen,
                    steps_per_epoch=len(X_train) // batch_size,
                    validation_steps=len(X_train) // batch_size,
                    epochs=10,
                    callbacks=[checkpoint,csvlogger])
# Out:
# Epoch 1/10
# 27/27 [==============================] - 16s 600ms/step - loss: 0.1569 - iou_score: 0.8782 - val_loss: 0.3055 - val_iou_score: 0.7998
# Epoch 2/10
# 27/27 [==============================] - 16s 590ms/step - loss: 0.2011 - iou_score: 0.8642 - val_loss: 0.2680 - val_iou_score: 0.8171
# Epoch 3/10
# 27/27 [==============================] - 16s 590ms/step - loss: 0.1813 - iou_score: 0.8691 - val_loss: 0.2574 - val_iou_score: 0.8278
# Epoch 4/10
# 27/27 [==============================] - 17s 624ms/step - loss: 0.1786 - iou_score: 0.8740 - val_loss: 0.2600 - val_iou_score: 0.8252
# Epoch 5/10
# 27/27 [==============================] - 17s 621ms/step - loss: 0.1685 - iou_score: 0.8820 - val_loss: 0.2562 - val_iou_score: 0.8289
# Epoch 6/10
# 27/27 [==============================] - 16s 595ms/step - loss: 0.1645 - iou_score: 0.8854 - val_loss: 0.2502 - val_iou_score: 0.8318
# Epoch 7/10
# 27/27 [==============================] - 17s 641ms/step - loss: 0.1766 - iou_score: 0.8832 - val_loss: 0.2407 - val_iou_score: 0.8375
# Epoch 8/10
# 27/27 [==============================] - 17s 620ms/step - loss: 0.1465 - iou_score: 0.8973 - val_loss: 0.2549 - val_iou_score: 0.8348
# Epoch 9/10
# 27/27 [==============================] - 16s 588ms/step - loss: 0.1625 - iou_score: 0.8920 - val_loss: 0.6709 - val_iou_score: 0.6538
# Epoch 10/10
# 27/27 [==============================] - 17s 629ms/step - loss: 0.1555 - iou_score: 0.8918 - val_loss: 0.2381 - val_iou_score: 0.8417

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
#acc = history.history['accuracy']
val_acc = history.history['val_iou_score']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

#IOU
y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(y_test, y_pred_thresholded)
union = np.logical_or(y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.8807471173534793

# %%
test_img_number = np.random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
print(test_img.shape)
test_img_input=np.expand_dims(test_img, 0)
ground_truth=y_test[test_img_number]
prediction = model.predict(test_img_input)
prediction = prediction[0,:,:,0]

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# (256, 256, 2)
